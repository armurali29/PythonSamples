# %%
 # def menu():
#     user_input_menu = int(input("ENTER 0 - To go to main menu: "))
#     if user_input_menu == 0:
#       user_input_entry = int(input(str_menu)) 
#     else:
#       print("Please check your entry")

existant_categories = {
"hazardous": ["Propane","Fertilizers"]
"organic": ["Vegetables","Meat"]
"recyclable":["Plastic","Metal"]
}

# str_menu = "\nPlease choose one of the following options:\n\nENTER 1 - To retrieve data from an existing waste category.\nENTER 2 - To add a new waste category.\nENTER 3 - To view all the waste categories.\n\nYour entry: "

# print("Hi! Welcome to Waste Management System.\n")

# while True:  
#  user_input_entry = int(input(str_menu))
#  if user_input_entry == 1:
#   print("Under construction")
#   user_input_menu = int(input("\n\nENTER 0 - To go to main menu: "))
#   if user_input_menu == 0:
#     continue
#   else:
#     print("Please check your entry")

#  elif user_input_entry == 2:
#   print("Under construction")
#   user_input_menu = int(input("\n\nENTER 0 - To go to main menu: "))
#   if user_input_menu == 0:
#     continue
#   else:
#     print("Please check your entry")

#  elif user_input_entry == 3:
#   print("Under construction")
#   user_input_menu = int(input("\n\nENTER 0 - To go to main menu: "))
#   if user_input_menu == 0:
#     continue
#   else:
#     print("Please check your entry")

#  else:
#   print("Please check your entry!")
#   user_input_menu = int(input("\n\nENTER 0 - To go to main menu: "))
#   if user_input_menu == 0:
#     continue
#   else:
#     print("Please check your entry")


  

#   if user_input_1 == 1:
#     user_input_2 = input("Please enter the waste category: ").lower()
# #     def waste_listing(category):
# #       for x in category:
# #         print(x)

# #   haz = ["Propane","Fertilizers"]
# #   org = ["Vegetables","Meat"]
# #   rec = ["Pastic","Metal"]

# #   if user_input_2 == "hazardous":
# #     waste_listing(haz)
# #   elif user_input_2 == "organic":
# #     waste_listing(org)
# #   elif user_input_2 == "recyclable":
# #     waste_listing(rec)
# #   else:
# #     print("Sorry, please check your spelling")
# # elif user_input_1 == 2:
# #   user_input_3 = input("Please type the new category name: ").lower()
# #   user_input_3 = input("Please list the wastes for '{}' separated by space: ".format(user_input_3))
# #   new_list_1 = user_input_3.split()
# #   print("Your list has been successfully created!\nHere is all the waste categories:")
# #   # def category_listing(achu):
# #   for x in :
# #       # print(category)
# #     print(x)
# #   # waste_listing(haz)
# #   # waste_listing(org)
# #   # waste_listing(rec)
# #   # waste_listing(new_list_1)
#   else:
#     print("Please check your selection")
# continue
